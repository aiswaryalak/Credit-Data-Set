# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('/content/credit_dataset.csv')
df
# Out:
#        Unnamed: 0       ID GENDER CAR REALITY  NO_OF_CHILD    INCOME  \
# 0               0  5008806      M   Y       Y            0  112500.0
# 1               1  5008808      F   N       Y            0  270000.0
# 2               2  5008809      F   N       Y            0  270000.0
# 3               3  5008810      F   N       Y            0  270000.0
# 4               4  5008811      F   N       Y            0  270000.0
# ...           ...      ...    ...  ..     ...          ...       ...
# 25129       25129  5149828      M   Y       Y            0  315000.0
# 25130       25130  5149834      F   N       Y            0  157500.0
# 25131       25131  5149838      F   N       Y            0  157500.0
# 25132       25132  5150049      F   N       Y            0  283500.0
# 25133       25133  5150337      M   N       Y            0  112500.0
#
#                 INCOME_TYPE                 EDUCATION_TYPE  \
# 0                   Working  Secondary / secondary special
# ...

# %%
sns.countplot(y="INCOME_TYPE", data=df)
# Out:
# <Axes: xlabel='count', ylabel='INCOME_TYPE'>

# %%
sns.countplot(y='EDUCATION_TYPE',data=df)
# Out:
# <Axes: xlabel='count', ylabel='EDUCATION_TYPE'>

# %%
sns.boxplot(x='AGE',y='HOUSE_TYPE',data=df)
# Out:
# <Axes: xlabel='AGE', ylabel='HOUSE_TYPE'>

# %%
sns.barplot(x='FAMILY SIZE',y='FAMILY_TYPE',data=df,ci=None)
# Out:
# <Axes: xlabel='FAMILY SIZE', ylabel='FAMILY_TYPE'>

# %%
sns.jointplot(x='AGE',y='FAMILY SIZE',data=df)

# %%
sns.countplot(y='HOUSE_TYPE',data=df)
# Out:
# <Axes: xlabel='count', ylabel='HOUSE_TYPE'>
